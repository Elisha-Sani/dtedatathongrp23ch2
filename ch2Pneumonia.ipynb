# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisha-Sani/dtedatathongrp23ch2/blob/main/ch2Pneumonia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PNEUMONIA STUDIES

# %%
#Importing pandas library
import pandas as pd

pd.set_option('display.max_colwidth', 100)

#Mounting drive
from google.colab import drive

drive.mount('/content/drive')

pneumonia_path = '/content/drive/MyDrive/Pneumonia-studies.csv'

df = pd.read_csv(pneumonia_path)

df.shape
# Out:
# Mounted at /content/drive
# (9640, 30)

# %%
#Displaying the data in the dataframe in list view
print(df)
# Out:
#        NCT Number  \
# 0     NCT02708225
# 1     NCT03962725
# 2     NCT04646525
# 3     NCT04333225
# 4     NCT04858425
# ...           ...
# 9635  NCT05380869
# 9636  NCT05137535
# 9637  NCT05669235
# 9638  NCT05313035
# 9639  NCT04909996
#
#                                                                                               Study Title  \
# 0     The Influence of Medical Clowns on the Performance of Pulmonary Function Tests Among Preschooler...
# 1                                                 Avoiding Neuromuscular Blockers to Reduce Complications
# 2         The Relationship Between Covid-19 Infection in Pediatric Patients and Secondary Lymphoid Organs
# 3                        Hydroxychloroquine in the Prevention of COVID-19 Infection in Healthcare Workers
# 4            Safety and Efficacy of Niclosamide in Patients With COVID-19 With Gastrointestinal Infection
# ...

# %%
#Displaying the first 10 rows
df.head(10)
# Out:
#     NCT Number  \
# 0  NCT02708225
# 1  NCT03962725
# 2  NCT04646525
# 3  NCT04333225
# 4  NCT04858425
# 5  NCT01964625
# 6  NCT04419025
# 7  NCT04569825
# 8  NCT03208725
# 9  NCT03325725
#
#                                                                                            Study Title  \
# 0  The Influence of Medical Clowns on the Performance of Pulmonary Function Tests Among Preschooler...
# 1                                              Avoiding Neuromuscular Blockers to Reduce Complications
# 2      The Relationship Between Covid-19 Infection in Pediatric Patients and Secondary Lymphoid Organs
# 3                     Hydroxychloroquine in the Prevention of COVID-19 Infection in Healthcare Workers
# 4         Safety and Efficacy of Niclosamide in Patients With COVID-19 With Gastrointestinal Infection
# 5  Positron Emission Tomography - Computed Tomography (PET-CT) Scanning in Chronic Graft Versus Hos...
# ...

# %%
#Displaying the last 10 rows
df.tail(10)
# Out:
#        NCT Number  \
# 9630  NCT04509713
# 9631  NCT01028313
# 9632  NCT04756869
# 9633  NCT04586413
# 9634  NCT05271669
# 9635  NCT05380869
# 9636  NCT05137535
# 9637  NCT05669235
# 9638  NCT05313035
# 9639  NCT04909996
#
#                                                                                               Study Title  \
# 9630                                                                            Canine COVID-19 Detection
# 9631  A Study of Panobinostat (LBH589) as Second-Line Therapy in Patients With Chronic Graft-Versus-Ho...
# 9632  Monitoring Health Care Workers at Risk for COVID-19 Using Wearable Sensors and Smartphone Techno...
# 9633  Post Acute COVID-19 Quality of Life (PAC-19QoL) Tool Development and Patient Registry (PAC-19QoL...
# 9634                                                              COVID-19 Immunity and Changes Over Time
# 9635                                                                          POCT PCT in Outpatient LRTI
# ...

# %%
#Basic structural information of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9640 entries, 0 to 9639
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  9640 non-null   object
#  1   Study Title                 9640 non-null   object
#  2   Study URL                   9640 non-null   object
#  3   Acronym                     3645 non-null   object
#  4   Study Status                9640 non-null   object
#  5   Brief Summary               9640 non-null   object
#  6   Study Results               9640 non-null   object
#  7   Conditions                  9640 non-null   object
#  8   Interventions               8226 non-null   object
#  9   Primary Outcome Measures    9452 non-null   object
#  10  Secondary Outcome Measures  7077 non-null   object
#  11  Other Outcome Measures      946 non-null    object
#  12  Sponsor                     9640 non-null   object
# ...

# %%
#Basic statistical analysis of numerical column
df.describe()
# Out:
#          Enrollment
# count  9.561000e+03
# mean   3.952972e+04
# std    1.982772e+06
# min    0.000000e+00
# 25%    5.000000e+01
# 50%    1.500000e+02
# 75%    5.000000e+02
# max    1.888141e+08
