# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisha-Sani/dtedatathongrp23ch2/blob/main/ch2Covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DECODING THE COVID19 DATA
# ##COVID 19
# 1. Importing pandas library.
# 2. Mounting our google drive.
# 3. Copying our file to drive for permanent storage.

# %%
#importing the pandas library
import pandas as pd

pd.set_option('display.max_colwidth', 100)

#Mounting our drive
from google.colab import drive
drive.mount('/content/drive')


covid_path = '/content/drive/MyDrive/covid19.csv'

df = pd.read_csv(covid_path)

df.shape
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (9342, 30)

# %% [markdown]
# #Calling the DataFrame
#
#
# * Since we saved our DataFrame as df, we are going to call it using *df*
# * When you run the code, it automatically displays the first 5 and the last 5 rows.
# * If we want to view only the first or last specific number of rows we use:
#
#
# > *First* - df.head(n)
#
# > *Last* - df.tail(n)
#
# > Where *n* is the number of rows

# %%
#Displaying the data
print(df)
# Out:
#        NCT Number  \
# 0     NCT04614025
# 1     NCT04646525
# 2     NCT04333225
# 3     NCT04996225
# 4     NCT04858425
# ...           ...
# 9337  NCT05137535
# 9338  NCT05669235
# 9339  NCT05584735
# 9340  NCT05313035
# 9341  NCT04909996
#
#                                                                                               Study Title  \
# 0          Open-label Multicenter Study to Evaluate the Efficacy of PLX-PAD for the Treatment of COVID-19
# 1         The Relationship Between Covid-19 Infection in Pediatric Patients and Secondary Lymphoid Organs
# 2                        Hydroxychloroquine in the Prevention of COVID-19 Infection in Healthcare Workers
# 3           Effect of Aerobics and Balancing Exercises on Anxiety and Dizziness in Patients With COVID-19
# 4            Safety and Efficacy of Niclosamide in Patients With COVID-19 With Gastrointestinal Infection
# ...

# %%
#displaying the first 10 rows
df.head(10)
# Out:
#     NCT Number  \
# 0  NCT04614025
# 1  NCT04646525
# 2  NCT04333225
# 3  NCT04996225
# 4  NCT04858425
# 5  NCT04419025
# 6  NCT04515225
# 7  NCT04594525
# 8  NCT04569825
# 9  NCT04510025
#
#                                                                                        Study Title  \
# 0   Open-label Multicenter Study to Evaluate the Efficacy of PLX-PAD for the Treatment of COVID-19
# 1  The Relationship Between Covid-19 Infection in Pediatric Patients and Secondary Lymphoid Organs
# 2                 Hydroxychloroquine in the Prevention of COVID-19 Infection in Healthcare Workers
# 3    Effect of Aerobics and Balancing Exercises on Anxiety and Dizziness in Patients With COVID-19
# 4     Safety and Efficacy of Niclosamide in Patients With COVID-19 With Gastrointestinal Infection
# 5     Efficacy of N-Acetylcysteine (NAC) in Preventing COVID-19 From Progressing to Severe Disease
# ...

# %%
#displaying the last 10 rows
df.tail(10)
# Out:
#        NCT Number  \
# 9332  NCT04509713
# 9333  NCT04756869
# 9334  NCT04954235
# 9335  NCT04586413
# 9336  NCT05271669
# 9337  NCT05137535
# 9338  NCT05669235
# 9339  NCT05584735
# 9340  NCT05313035
# 9341  NCT04909996
#
#                                                                                               Study Title  \
# 9332                                                                            Canine COVID-19 Detection
# 9333  Monitoring Health Care Workers at Risk for COVID-19 Using Wearable Sensors and Smartphone Techno...
# 9334  Effectiveness and Safety Study of Specific Hyperimmune Equine Serum for the Treatment of Severe ...
# 9335  Post Acute COVID-19 Quality of Life (PAC-19QoL) Tool Development and Patient Registry (PAC-19QoL...
# 9336                                                              COVID-19 Immunity and Changes Over Time
# 9337                       A Study of the Infection and Transmission of SARS-CoV-2 in Paediatric Patients
# ...

# %% [markdown]
# #INFO AND DESCRIBE FUNCTIONALITY
# ##INFO
# * Used to display basic information about columns involving the data stored in the dataframe.
# * May include;
# >> 1. Column name
# >> 2. Data types
# >> 3. Count of rows in each column
# >> 4. Whether null or not null
# * Format: *df.info()*
#
# ##DESCRIBE
# * Used in giving a statistical summary of the numerical columns.
# * Include;
# >> 1. Count
# >> 2. Mean
# >> 3. Standard Deviation
# >> 4. Min
# >> 5. Percentages
# >> 6. Max

# %%
#Viewing basic information about the file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9342 entries, 0 to 9341
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  9342 non-null   object
#  1   Study Title                 9342 non-null   object
#  2   Study URL                   9342 non-null   object
#  3   Acronym                     3610 non-null   object
#  4   Study Status                9342 non-null   object
#  5   Brief Summary               9342 non-null   object
#  6   Study Results               9342 non-null   object
#  7   Conditions                  9342 non-null   object
#  8   Interventions               7992 non-null   object
#  9   Primary Outcome Measures    9304 non-null   object
#  10  Secondary Outcome Measures  6822 non-null   object
#  11  Other Outcome Measures      926 non-null    object
#  12  Sponsor                     9342 non-null   object
# ...

# %%
#Statistical summary of the numerical column
df.describe()
# Out:
#          Enrollment
# count  9.305000e+03
# mean   5.049117e+04
# std    2.118949e+06
# min    0.000000e+00
# 25%    5.000000e+01
# 50%    1.500000e+02
# 75%    5.000000e+02
# max    1.888141e+08
