# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisha-Sani/dtedatathongrp23ch2/blob/main/ch2Malaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##MALARIA STUDIES

# %%
#Importing the pandas library
import pandas as pd

pd.set_option('display.max_colwidth', 100)

#mounting drive
from google.colab import drive

drive.mount('/content/drive')

malaria_path = '/content/drive/MyDrive/Malaria-studies.csv'

df = pd.read_csv(malaria_path)

df.shape
# Out:
# Mounted at /content/drive
# (1330, 30)

# %%
#Displaying the data stored in the dataframe
print(df)
# Out:
#        NCT Number  \
# 0     NCT01976325
# 1     NCT00914225
# 2     NCT05605925
# 3     NCT01464125
# 4     NCT02557425
# ...           ...
# 1325  NCT02700269
# 1326  NCT01575613
# 1327  NCT03963869
# 1328  NCT00460369
# 1329  NCT04969913
#
#                                                                                               Study Title  \
# 0                                                              Evaluating the Ottawa Malaria Decision Aid
# 1     Effect of Bednets and a Water Purification Device on HIV Disease Progression Among ART naïve Pat...
# 2                                   Ivermectin-artemisinin Combination Therapy for Eradication of Malaria
# 3     Fosmidomycin and Azithromycin for Acute Uncomplicated Plasmodium Falciparum Malaria (P. Malaria)...
# 4                                Prophylaxis Against Malaria to Enhance Child Development (PROTECT Study)
# ...

# %%
#Displaying the first 10 rows in the dataframe
df.head(10)
# Out:
#     NCT Number  \
# 0  NCT01976325
# 1  NCT00914225
# 2  NCT05605925
# 3  NCT01464125
# 4  NCT02557425
# 5  NCT02905019
# 6  NCT05946642
# 7  NCT00442442
# 8  NCT02556242
# 9  NCT00259142
#
#                                                                                            Study Title  \
# 0                                                           Evaluating the Ottawa Malaria Decision Aid
# 1  Effect of Bednets and a Water Purification Device on HIV Disease Progression Among ART naïve Pat...
# 2                                Ivermectin-artemisinin Combination Therapy for Eradication of Malaria
# 3  Fosmidomycin and Azithromycin for Acute Uncomplicated Plasmodium Falciparum Malaria (P. Malaria)...
# 4                             Prophylaxis Against Malaria to Enhance Child Development (PROTECT Study)
# 5                                            A Safety and Efficacy Study of R21 +/- ChAd63/MVA ME-TRAP
# ...

# %%
#Displaying the last 10 rows in the dataframe
df.tail(10)
# Out:
#        NCT Number  \
# 1320  NCT02810613
# 1321  NCT02168569
# 1322  NCT04158713
# 1323  NCT01921413
# 1324  NCT04778813
# 1325  NCT02700269
# 1326  NCT01575613
# 1327  NCT03963869
# 1328  NCT00460369
# 1329  NCT04969913
#
#                                                                                               Study Title  \
# 1320                                                     Leiden University Medical Center Mini Donor Bank
# 1321        In Vivo Efficacy of Artemether-lumefantrine and Amodiaquine-artesunate in Mozambican Children
# 1322                         Improving PRegnancy Outcomes With PReVEntive Therapy in Africa-2 (IMPROVE-2)
# 1323                                   Clinical Performance Evaluation of Fyodor Urine Malaria Test (UMT)
# 1324  Evaluation of Three Artemisinin-based Combinations for the Treatment of Uncomplicated Malaria in...
# 1325                                          Vanderbilt-Zambia Innovations in Global Health Technologies
# ...

# %%
#Displaying basic structural information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  1330 non-null   object
#  1   Study Title                 1330 non-null   object
#  2   Study URL                   1330 non-null   object
#  3   Acronym                     445 non-null    object
#  4   Study Status                1330 non-null   object
#  5   Brief Summary               1330 non-null   object
#  6   Study Results               1330 non-null   object
#  7   Conditions                  1330 non-null   object
#  8   Interventions               1204 non-null   object
#  9   Primary Outcome Measures    1271 non-null   object
#  10  Secondary Outcome Measures  1095 non-null   object
#  11  Other Outcome Measures      135 non-null    object
#  12  Sponsor                     1330 non-null   object
# ...

# %%
#Basic analitical statistics summary for numerical column
df.describe()
# Out:
#           Enrollment
# count    1316.000000
# mean     3448.317629
# std     19164.457595
# min         0.000000
# 25%        54.000000
# 50%       256.000000
# 75%      1052.250000
# max    393387.000000
