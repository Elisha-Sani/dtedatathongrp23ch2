# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisha-Sani/dtedatathongrp23ch2/blob/main/ch2HivStudies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##HIV STUDIES

# %%
#Importing the pandas library
import pandas as pd

pd.set_option('display.max_colwidth', 100)

#Mounting the drive
from google.colab import drive

drive.mount('/content/drive')


HIV_path = '/content/drive/MyDrive/HIVStudies.csv'

df = pd.read_csv(HIV_path, skiprows=[8019])


df.shape
# Out:
# Mounted at /content/drive
# (9112, 30)

# %%
#Displaying the data stored in the dataframe for better viewing
print(df)
# Out:
#        NCT Number  \
# 0     NCT00914225
# 1     NCT02167425
# 2     NCT01423825
# 3     NCT02098525
# 4     NCT04515225
# ...           ...
# 9107  NCT05537935
# 9108  NCT02038335
# 9109  NCT02891135
# 9110  NCT01888835
# 9111  NCT00158535
#
#                                                                                               Study Title  \
# 0     Effect of Bednets and a Water Purification Device on HIV Disease Progression Among ART naïve Pat...
# 1        Study of Integrating Antiretroviral Therapy With Methadone Treatment for People Who Inject Drugs
# 2     Evaluating the Safety and Immune Response to an HIV Vaccine Boost Following the Administration o...
# 3     Clinical Outcomes of Cryptococcal Meningitis Among HIV-infected Patients in the Era of Antiretro...
# 4                                                            COVID-19 Prevalence in HIV-infected Patients
# ...

# %%
#Displaying the first 10 rows
df.head(10)
# Out:
#     NCT Number  \
# 0  NCT00914225
# 1  NCT02167425
# 2  NCT01423825
# 3  NCT02098525
# 4  NCT04515225
# 5  NCT03732625
# 6  NCT03208725
# 7  NCT00002225
# 8  NCT00002025
# 9  NCT03848325
#
#                                                                                            Study Title  \
# 0  Effect of Bednets and a Water Purification Device on HIV Disease Progression Among ART naïve Pat...
# 1     Study of Integrating Antiretroviral Therapy With Methadone Treatment for People Who Inject Drugs
# 2  Evaluating the Safety and Immune Response to an HIV Vaccine Boost Following the Administration o...
# 3  Clinical Outcomes of Cryptococcal Meningitis Among HIV-infected Patients in the Era of Antiretro...
# 4                                                         COVID-19 Prevalence in HIV-infected Patients
# 5  Neuropsyquiatric Evolution After Introduction of Raltegravir QD in Substitution of Dolutegravir:...
# ...

# %%
#displaying the last 10 files
df.tail(10)
# Out:
#        NCT Number  \
# 9102  NCT00513513
# 9103  NCT00824369
# 9104  NCT03058835
# 9105  NCT00491335
# 9106  NCT00011635
# 9107  NCT05537935
# 9108  NCT02038335
# 9109  NCT02891135
# 9110  NCT01888835
# 9111  NCT00158535
#
#                                                                                               Study Title  \
# 9102  TMC114-C227: A Study to Evaluate the Effectiveness and Safety of TMC114 (Darunavir) With a Low D...
# 9103       A Rollover Study For Subjects Discontinuing From UK-453,061 Studies For The Treatment Of HIV-1
# 9104  IN-US-276-1340: Pre-Exposure Prophylaxis to Prevent HIV Acquisition in US Women: A Demonstration...
# 9105  HIV Infection and Tobacco Use Among Injection Drug Users in Baltimore, Maryland: A Pilot Study o...
# 9106                                      The Effect of Milk Thistle on the Pharmacokinetics of Indinavir
# 9107                                                    Low Dose Naltrexone for Pain in Patients With HIV
# ...

# %%
#Displaying the basic structure of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9112 entries, 0 to 9111
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  9112 non-null   object
#  1   Study Title                 9112 non-null   object
#  2   Study URL                   9112 non-null   object
#  3   Acronym                     2689 non-null   object
#  4   Study Status                9112 non-null   object
#  5   Brief Summary               9112 non-null   object
#  6   Study Results               9112 non-null   object
#  7   Conditions                  9112 non-null   object
#  8   Interventions               8150 non-null   object
#  9   Primary Outcome Measures    7562 non-null   object
#  10  Secondary Outcome Measures  6031 non-null   object
#  11  Other Outcome Measures      662 non-null    object
#  12  Sponsor                     9112 non-null   object
# ...

# %%
#Basic statistical analitical summary of numerical column
df.describe()
# Out:
#          Enrollment
# count  8.736000e+03
# mean   6.833751e+03
# std    2.771885e+05
# min    0.000000e+00
# 25%    3.600000e+01
# 50%    1.000000e+02
# 75%    3.700000e+02
# max    1.883761e+07
