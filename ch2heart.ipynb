# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisha-Sani/dtedatathongrp23ch2/blob/main/ch2heart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DECODING THE HEART.CSV
# ## PROCESSES
#
# 1. Importing the required libraries or features.
# 2. Mounting drive and saving the data to the drive.
# 3. Decoding the data

# %%
import pandas as pd

from google.colab import drive


drive.mount('/content/drive')

# pd.options.display.max_rows = None
# pd.options.display.max_columns = None


heart_path = '/content/drive/MyDrive/heart.csv'

df = pd.read_csv(heart_path, skiprows=[2203])

pd.set_option('display.max_colwidth', 100)

df.shape
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (2202, 30)

# %%
#Displaying the data stored in the dataframe in text format for better viewing and understanding
print(df)
# Out:
#        NCT Number  \
# 0     NCT00291525
# 1     NCT03419325
# 2     NCT03176225
# 3     NCT00199225
# 4     NCT05724225
# ...           ...
# 2197  NCT03746847
# 2198  NCT04252547
# 2199  NCT02188147
# 2200  NCT00860847
# 2201  NCT01205347
#
#                                                                                               Study Title  \
# 0                                                                   Randomized On-X Anticoagulation Trial
# 1                                               A Genomic Approach for Clopidogrel in Caribbean Hispanics
# 2     Evaluate Safety and Effectiveness of XenoSure Biological Patch in the Application of Cardiac Repair
# 3              Evaluation of Possible Effects on the QT/ QTc Interval of Rupatadine in Healthy Volunteers
# 4             "Atriogenic Tricuspid Selected, Omics Profile, Multimodality Imaging and Clinical Outcomes"
# ...

# %%
#Displaying the first 10 rows stored in the dataframe
df.head(10)
# Out:
#     NCT Number  \
# 0  NCT00291525
# 1  NCT03419325
# 2  NCT03176225
# 3  NCT00199225
# 4  NCT05724225
# 5  NCT03940625
# 6  NCT00442325
# 7  NCT04032925
# 8  NCT03458325
# 9  NCT03289325
#
#                                                                                            Study Title  \
# 0                                                                Randomized On-X Anticoagulation Trial
# 1                                            A Genomic Approach for Clopidogrel in Caribbean Hispanics
# 2  Evaluate Safety and Effectiveness of XenoSure Biological Patch in the Application of Cardiac Repair
# 3           Evaluation of Possible Effects on the QT/ QTc Interval of Rupatadine in Healthy Volunteers
# 4          "Atriogenic Tricuspid Selected, Omics Profile, Multimodality Imaging and Clinical Outcomes"
# 5  Anthracycline Induced Cardiotoxicity - Early Detection by Combination of Diastolic Strain and T2...
# ...

# %%
#Displaying the last 10 rows stored in the dataframe
df.tail(10)
# Out:
#        NCT Number  \
# 2192  NCT02446522
# 2193  NCT01285622
# 2194  NCT00384722
# 2195  NCT04754022
# 2196  NCT02515747
# 2197  NCT03746847
# 2198  NCT04252547
# 2199  NCT02188147
# 2200  NCT00860847
# 2201  NCT01205347
#
#                                                                                             Study Title  \
# 2192         Compare Endoscopic and Open Methods of Vein Harvesting for Coronary Artery Bypass Grafting
# 2193                           Plethysmography Variability Index as an Indicator of Adequacy of Preload
# 2194                                                                           EASYTRAK 3 Downsize Lead
# 2195                            Transfusion Requirements in Younger Patients Undergoing Cardiac Surgery
# 2196                             Prospective Russian Evaluation of Lp(a) Role in cardiovascUlar DiseasE
# 2197                                         PET Imaging in Patients With Suspected Cardiac Sarcoidosis
# ...

# %%
#Determining the basic structural information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2202 entries, 0 to 2201
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  2202 non-null   object
#  1   Study Title                 2202 non-null   object
#  2   Study URL                   2202 non-null   object
#  3   Acronym                     964 non-null    object
#  4   Study Status                2202 non-null   object
#  5   Brief Summary               2202 non-null   object
#  6   Study Results               2202 non-null   object
#  7   Conditions                  2202 non-null   object
#  8   Interventions               1816 non-null   object
#  9   Primary Outcome Measures    2098 non-null   object
#  10  Secondary Outcome Measures  1574 non-null   object
#  11  Other Outcome Measures      175 non-null    object
#  12  Sponsor                     2202 non-null   object
# ...

# %%
#summary analysis of the numerical columns
df.describe()
# Out:
#          Enrollment
# count  2.153000e+03
# mean   5.485707e+03
# std    8.430046e+04
# min    0.000000e+00
# 25%    4.300000e+01
# 50%    1.020000e+02
# 75%    3.500000e+02
# max    2.240000e+06
